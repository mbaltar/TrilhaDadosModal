# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização de dados
import matplotlib.pyplot as plt

# Importação de dados financeiros
import yfinance as yf
import quandl

# %%
ibov = pd.read_csv('Bovespa.csv')

# %%
ibov.head()
# Out:
#         Date     ABCB4      BBAS3      BBDC4  BPAN4    BTOW3      CGAS3  \
# 0   6/5/2012  5.778904  13.193346  14.825962    NaN  4.67417  21.089613
# 1   6/6/2012  5.784656  13.474055  15.421063    NaN  4.95184  21.367132
# 2   6/8/2012  5.836405  13.488092  15.457347    NaN  5.08142  22.088638
# 3  6/11/2012  5.922663  13.614412  15.628112    NaN  5.09993  22.088638
# 4  6/12/2012  5.876658  13.614412  15.886813    NaN  5.34984  22.088638
#
#        CMIG4     CSNA3      CYRE3  ...     POMO4     QGEP3     RAPT4  \
# 0  16.403233  9.799454  13.011072  ...  3.559332  7.938090  6.136378
# 1  17.082111  9.838496  13.979592  ...  3.727821  8.013066  6.316431
# 2  17.082111  9.799454  14.025277  ...  3.694127  7.825626  6.338035
# 3  17.120369  9.705755  13.723758  ...  3.753094  7.413257  6.482082
# 4  17.689350  9.736986  13.632388  ...  3.799433  7.413257  6.482082
#
#       SAPR4      SBSP3     SUZB5      TUPY3     USIM5      VALE5     WEGE3
# ...

# %%
ibov.WEGE3.plot();

# %%
data = pd.read_csv('WDO_MT5_sample.txt')

# %%
data.head()
# Out:
#                   time               time.1      open      high       low  \
# 0  2021-11-08 11:59:00  2021-11-08 11:59:00  5692.411  5692.922  5690.878
# 1  2021-11-08 12:00:00  2021-11-08 12:00:00  5691.900  5693.943  5691.389
# 2  2021-11-08 12:01:00  2021-11-08 12:01:00  5693.432  5693.943  5692.411
# 3  2021-11-08 12:02:00  2021-11-08 12:02:00  5693.943  5693.943  5692.411
# 4  2021-11-08 12:03:00  2021-11-08 12:03:00  5693.432  5693.943  5691.900
#
#       close  tick_volume  spread  real_volume
# 0  5691.900         2140       1         6413
# 1  5693.943         1547       1         5209
# 2  5693.943         1146       1         4500
# 3  5693.943          685       1         2227
# 4  5691.900          922       1         3612

# %%
data['time'] = pd.to_datetime(data['time'])
data.index = data['time']

data.head()
# Out:
#                                    time               time.1      open  \
# time
# 2021-11-08 11:59:00 2021-11-08 11:59:00  2021-11-08 11:59:00  5692.411
# 2021-11-08 12:00:00 2021-11-08 12:00:00  2021-11-08 12:00:00  5691.900
# 2021-11-08 12:01:00 2021-11-08 12:01:00  2021-11-08 12:01:00  5693.432
# 2021-11-08 12:02:00 2021-11-08 12:02:00  2021-11-08 12:02:00  5693.943
# 2021-11-08 12:03:00 2021-11-08 12:03:00  2021-11-08 12:03:00  5693.432
#
#                          high       low     close  tick_volume  spread  \
# time
# 2021-11-08 11:59:00  5692.922  5690.878  5691.900         2140       1
# 2021-11-08 12:00:00  5693.943  5691.389  5693.943         1547       1
# 2021-11-08 12:01:00  5693.943  5692.411  5693.943         1146       1
# 2021-11-08 12:02:00  5693.943  5692.411  5693.943          685       1
# 2021-11-08 12:03:00  5693.943  5691.900  5691.900          922       1
#
#                      real_volume
# time
# 2021-11-08 11:59:00         6413
# ...

# %%
data.close.plot();

# %%
data.columns
# Out:
# Index(['time', 'time.1', 'open', 'high', 'low', 'close', 'tick_volume',
#        'spread', 'real_volume'],
#       dtype='object')

# %%
data.shape
# Out:
# (40000, 9)

# %%
data.dtypes
# Out:
# time           datetime64[ns]
# time.1                 object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# tick_volume             int64
# spread                  int64
# real_volume             int64
# dtype: object

# %%
data.close.max()
# Out:
# 5854.552

# %%
data.close.min()
# Out:
# 5137.5

# %%
data.close.mean()
# Out:
# 5605.071517374926

# %%
data.close.median()
# Out:
# 5674.02

# %%
data.close.mode()
# Out:
# 0    5725.105
# Name: close, dtype: float64

# %%
data.close.std()
# Out:
# 187.79991661149765

# %%
data.close.var()
# Out:
# 35268.80867928547

# %%
retornos = data.close.pct_change()
retornos
# Out:
# time
# 2021-11-08 11:59:00         NaN
# 2021-11-08 12:00:00    0.000359
# 2021-11-08 12:01:00    0.000000
# 2021-11-08 12:02:00    0.000000
# 2021-11-08 12:03:00   -0.000359
#                          ...
# 2022-02-17 13:51:00    0.000000
# 2022-02-17 13:52:00   -0.000097
# 2022-02-17 13:53:00   -0.000097
# 2022-02-17 13:54:00    0.000000
# 2022-02-17 13:55:00    0.000097
# Name: close, Length: 40000, dtype: float64

# %%
retornos.std()
# Out:
# 0.00038607281252826017

# %%
retornos.plot.hist(bins=40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.boxplot(column='close');

# %%
ibov.corr()
# Out:
#           ABCB4     BBAS3     BBDC4     BPAN4     BTOW3     CGAS3     CMIG4  \
# ABCB4  1.000000  0.802466  0.880064  0.180851 -0.167556  0.911855 -0.342822
# BBAS3  0.802466  1.000000  0.868918  0.266910  0.245779  0.689391 -0.048224
# BBDC4  0.880064  0.868918  1.000000  0.158674  0.119928  0.833946 -0.265528
# BPAN4  0.180851  0.266910  0.158674  1.000000  0.429124 -0.046854  0.521156
# BTOW3 -0.167556  0.245779  0.119928  0.429124  1.000000 -0.121103  0.236786
# CGAS3  0.911855  0.689391  0.833946 -0.046854 -0.121103  1.000000 -0.462031
# CMIG4 -0.342822 -0.048224 -0.265528  0.521156  0.236786 -0.462031  1.000000
# CSNA3  0.347341  0.400193  0.304357 -0.109402 -0.007519  0.398764  0.174453
# CYRE3 -0.133787 -0.003426 -0.234965  0.415004 -0.143738 -0.223291  0.643327
# ELET3  0.753930  0.589273  0.722583 -0.203811 -0.286010  0.741943 -0.173920
# ELPL4  0.180321  0.143745  0.190638 -0.001084 -0.248903  0.043039  0.364071
# ...

# %%
yf.download('PETR4.SA', start='2022-02-01', end='2022-02-18', period="1d")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-02-01  32.349998  33.320000  31.950001  33.000000  30.164644  57315200
# 2022-02-02  33.410000  33.490002  32.360001  32.520000  29.725887  36271700
# 2022-02-03  32.349998  32.919998  31.620001  32.070000  29.314550  51087800
# 2022-02-04  32.410000  33.230000  31.879999  32.630001  29.826435  59346800
# 2022-02-07  32.549999  32.779999  32.130001  32.150002  29.387678  48868100
# 2022-02-08  31.900000  31.950001  31.260000  31.830000  29.095171  62590000
# 2022-02-09  31.740000  32.689999  31.650000  31.950001  29.204861  50960500
# 2022-02-10  32.299999  32.900002  31.940001  32.439999  29.652758  49534600
# 2022-02-11  32.770000  33.910000  32.630001  33.759998  30.859344  88013400
# 2022-02-14  33.860001  33.939999  32.820000  33.000000  30.164644  55687000
# ...

# %%
brml3 = yf.Ticker('BRML3.SA')
type(brml3)
# Out:
# yfinance.ticker.Ticker

# %%
brml3.info
# Out:
# {'zip': '22430-041',
#  'sector': 'Real Estate',
#  'longBusinessSummary': 'BR Malls Participações S.A. operates and manages shopping malls in Brazil. It also promotes and manages real estate enterprises; manages parking lot operations; and offers digital solutions to support shopping malls and retail companies. The company was founded in 1949 and is headquartered in Rio de Janeiro, Brazil.',
#  'city': 'Rio De Janeiro',
#  'phone': '55 21 3138 9900',
#  'state': 'RJ',
#  'country': 'Brazil',
#  'companyOfficers': [],
#  'website': 'https://ri.brmalls.com.br',
#  'maxAge': 1,
#  'address1': 'Av. Borges de Medeiros, 633',
#  'fax': '55 21 3138 9901',
#  'industry': 'Real Estate Services',
#  'address2': '1º andar Leblon',
#  'ebitdaMargins': 0.63474,
#  'profitMargins': 0.16892,
#  'grossMargins': 0.89295995,
#  'operatingCashflow': 646337984,
#  'revenueGrowth': 0.474,
#  'operatingMargins': 0.5877,
#  'ebitda': 761046016,
#  'targetLowPrice': 9,
#  'recommendationKey': 'buy',
# ...

# %%
brml3.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2010-05-03   0.081020          0.00
# 2010-05-04   0.081619          0.00
# 2010-09-24   0.000000          2.00
# 2011-05-02   0.110514          0.00
# 2012-04-25   0.100774          0.00
# 2013-05-02   0.315383          0.00
# 2014-05-02   0.210383          0.00
# 2014-12-04   0.103443          0.00
# 2015-05-04   0.306114          0.00
# 2016-05-02   0.000000          1.30
# 2017-05-02   0.066226          1.15
# 2018-11-27   0.083109          0.00
# 2018-12-26   0.011872          0.00
# 2019-03-29   0.065233          0.00
# 2019-05-02   0.083294          0.00
# 2019-05-29   0.065233          0.00
# 2019-08-08   0.825986          0.00
# 2022-05-02   0.053610          0.00

# %%
brml3.info['dividendRate']
# Out:
# 0.05

# %%
# Preço/Lucro
brml3.info['forwardPE']
# Out:
# 12.691176

# %%
# MarketCap
brml3.info['marketCap']
# Out:
# 7148004352

# %%
# Média dos volumes transacionados nos últimos 10 dias
brml3.info['averageVolume10days']
# Out:
# 15317770

# %%
# Investidores institucionais
brml3.institutional_holders
# Out:
#                                               Holder    Shares Date Reported  \
# 0                               New World Fund, Inc.  56754185    2022-01-30
# 1  Vanguard International Stock Index-Emerging Ma...  12068880    2022-01-30
# 2  Vanguard International Stock Index-Total Intl ...  10850692    2022-01-30
# 3             iShares Core MSCI Emerging Markets ETF   6650472    2022-02-27
# 4                       Emerging Markets Growth Fund   6080839    2021-12-30
# 5   American Fds Developing World Growth & Income Fd   5124793    2022-02-27
# 6        American Funds Insurance Ser-New World Fund   4194387    2021-12-30
# 7     Vanguard Global ex U.S. Real Estate Index Fund   4099453    2022-01-30
# 8         DFA Emerging Markets Core Equity Portfolio   3685040    2022-01-30
# 9              DFA Emerging Markets Small Cap Series   3040792    2022-01-30
#
#     % Out      Value
# 0  0.0685  546542801
# 1  0.0146  116223314
# 2  0.0131  104492163
# 3  0.0080   62580941
# ...

# %%
# Resultados trimestrais
brml3.quarterly_earnings
# Out:
#            Revenue   Earnings
# Quarter
# 2Q2021   239239000 -112997000
# 3Q2021   290490000   57149000
# 4Q2021   335333000  186276000
# 1Q2022   333927000   72104000

# %%
# Calendário de resultados
brml3.calendar
# Out:
#                                 Value
# Earnings Date     2022-08-11 19:00:00
# Earnings Average                 None
# Earnings Low                     None
# Earnings High                    None
# Revenue Average             358006000
# Revenue Low                 348580000
# Revenue High                403700000

# %%
# Importando múltiplos ativos para um dataframe

dados = yf.download('BBAS3.SA BPAC11.SA BBDC4.SA', start='2019-01-01', end='2021-12-31')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
dados.head()
# Out:
#             Adj Close                           Close                       \
#              BBAS3.SA   BBDC4.SA BPAC11.SA   BBAS3.SA   BBDC4.SA BPAC11.SA
# Date
# 2019-01-02  39.501381  21.647638  5.773697  48.599998  25.288004    6.2250
# 2019-01-03  39.663948  21.866940  6.012528  48.799999  25.532181    6.4825
# 2019-01-04  39.663948  21.695349  6.225854  48.799999  25.331829    6.7125
# 2019-01-07  39.403858  21.952742  6.353385  48.480000  25.632357    6.8500
# 2019-01-08  38.956833  22.086790  6.235074  47.930000  25.788879    6.5525
#
#                  High                             Low                       \
#              BBAS3.SA   BBDC4.SA BPAC11.SA   BBAS3.SA   BBDC4.SA BPAC11.SA
# Date
# 2019-01-02  49.700001  25.538443    6.2325  46.090000  24.054596    5.9125
# 2019-01-03  49.200001  25.601051    6.4975  47.849998  24.943651    6.1150
# 2019-01-04  49.830002  25.838968    6.7175  47.919998  25.043825    6.4600
# ...

# %%
dados = yf.download('BBAS3.SA BPAC11.SA BBDC4.SA', start='2019-01-01', end='2021-12-31', group_by='tickers')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
dados.head()
# Out:
#              BBDC4.SA                                                          \
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2019-01-02  24.198597  25.538443  24.054596  25.288004  21.647644  37247502.0
# 2019-01-03  25.231655  25.601051  24.943651  25.532181  21.866941  31131823.0
# 2019-01-04  25.325569  25.838968  25.043825  25.331829  21.695347  23808981.0
# 2019-01-07  25.262960  25.851490  25.262960  25.632357  21.952738  30560665.0
# 2019-01-08  25.701227  25.795141  25.037565  25.788879  22.086792  33927722.0
#
#              BBAS3.SA                                                          \
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2019-01-02  46.200001  49.700001  46.090000  48.599998  39.501400  14905300.0
# 2019-01-03  48.500000  49.200001  47.849998  48.799999  39.663948   8879100.0
# 2019-01-04  48.080002  49.830002  47.919998  48.799999  39.663948   8859200.0
# ...

# %%
# Histórico máximo de dados de um determinado ativo

vale = yf.Ticker('VALE3.SA')
vale_historico = vale.history(period='max', interval='1wk')

# %%
vale_historico
# Out:
#                  Open       High        Low      Close       Volume  \
# Date
# 2000-01-03   1.795995   1.826355   1.731852   1.817375    9384000.0
# 2000-01-10   1.924280   2.095327   1.924280   2.095327   11980800.0
# 2000-01-17   2.095327   2.138088   2.009803   2.009803    6720000.0
# 2000-01-24   2.009804   2.073946   2.009804   2.052566    1800000.0
# 2000-01-31   2.052566   2.052566   1.902899   1.996975    5616000.0
# ...               ...        ...        ...        ...          ...
# 2022-04-18  91.610001  92.000000  80.080002  80.449997  118057400.0
# 2022-04-25  77.940002  87.199997  77.540001  83.290001  228946900.0
# 2022-05-02  83.160004  84.209999  78.250000  79.760002  148981100.0
# 2022-05-09  77.529999  79.889999  74.870003  77.809998  156712600.0
# 2022-05-16  78.680000  82.459999  77.419998  81.260002  152122100.0
#
#             Dividends  Stock Splits
# Date
# 2000-01-03        0.0           0.0
# 2000-01-10        0.0           0.0
# ...

# %% [markdown]
# ### Obtenção da dados via API Quandl
#
# Vamos utilizar a API da Quandl (Nasdaq). Trata-se de uma API famosa dentro do mercado financeiro utilizado por centenas de empresas pra obtenção de dados.
# Possui tanto repositórios gratuitos quanto pagos.
# Podemos obter os principais indicadores macroeconômicos com essa API.

# %%
# Inserir a chave de API
quandl.ApiConfig.api_key = 'E4NszAgPfgyuJCTJRqrF'

# Dados da Selic
selic = quandl.get('BCB/432', start='2000-01-01', end_date='2021-12-31')

plt.figure(figsize=(10, 10))
plt.plot(selic)
plt.show()

# %%
quandl.get('BCB/432', start_date='2000-01-01', end_date='2021-12-31').plot();

# %%
# IPCA

ipca  = quandl.get('BCB/13522', start_date='2000-01-01').plot();

# %%
# Dólar

dolar = quandl.get('BCB/10813', start_date='2010-01-01').plot();

# %%
# CDI

cdi = quandl.get('BCB/4392', start_date='2010-01-01').plot();

# %%
# IGPM

igpm = quandl.get('BCB/189', start_date='2010-01-01').plot();

# %%
# incc

incc = quandl.get('BCB/7458', start_date='2010-01-01').plot();

# %%
# Salário mínimo

salario_minimo = quandl.get('BCB/1619', start_date='2010-01-01').plot();

# %%
# Reservas internacionais

reservas = quandl.get('BCB/13982', start_date='2010-01-01').plot();

# %%
# PIB em dólares

pib_brasil = quandl.get('ODA/BRA_NGDPD', start_date='2010-01-01').plot();

# %%
# indicadores internacionais

inflacao_usa = quandl.get('RATEINF/CPI_USA', start_date='2010-01-01').plot();

# %%
inflacao_euro = quandl.get('RATEINF/CPI_EUR', start_date='2010-01-01').plot();

# %%
inflacao_alemanha = quandl.get('RATEINF/CPI_DEU', start_date='2010-01-01').plot();

# %%
inflacao_japao = quandl.get('RATEINF/CPI_JPN', start_date='2010-01-01').plot();

# %%
# Bitcoin Market Price USD
bitcoin = quandl.get('BCHAIN/MKPRU', start_date='2010-01-01').plot();

# %%
# Bitcoin USD Exchange Trade Vol
bitcoin_volume = quandl.get('BCHAIN/TRVOU', start_date='2010-01-01').plot();

# %%
# Bitcoin Miners Revenue
bitcoin_miners_rev = quandl.get('BCHAIN/MIREV', start_date='2010-01-01').plot();
