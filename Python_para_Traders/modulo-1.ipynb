# %%
import pandas as pd

arquivo = pd.read_csv('WEGE3.SA.csv')
arquivo.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 1  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 3  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 4  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0
# 5  2017-07-31  7.211538  7.303846  7.211538  7.284615   6.915902  2787980.0
# 6  2017-08-01  7.307692  7.480769  7.265384  7.365384   6.992584  4247360.0
# 7  2017-08-02  7.369230  7.569230  7.369230  7.507692   7.127687  5018520.0
# 8  2017-08-03  7.523076  7.561538  7.311538  7.373076   6.999886  3764280.0
# 9  2017-08-04  7.403846  7.442307  7.342307  7.361538   6.988931  2427360.0

# %%
# Visualização de dados
arquivo.Close.plot()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-3cfaccho because the default path (/home/mbaltar/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# <AxesSubplot:>

# %%
# Manipulação de dados

# Colocando a data no índice do dataframe
arquivo.index = arquivo.Date
arquivo.head()
# Out:
#                   Date      Open      High       Low     Close  Adj Close  \
# Date
# 2017-07-24  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007
# 2017-07-25  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235
# 2017-07-26  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069
# 2017-07-27  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296
# 2017-07-28  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570
#
#                Volume
# Date
# 2017-07-24  2638220.0
# 2017-07-25  2505880.0
# 2017-07-26  2112240.0
# 2017-07-27  1910480.0
# 2017-07-28  2866760.0

# %%
# aí pode remover a coluna Date
arquivo.drop(["Date"], axis=1, inplace=True)
arquivo.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %%
# Criando um dataframe a partir do original
cotacoes = arquivo.copy()
cotacoes.drop(['Volume'], axis=1, inplace=True)
cotacoes.tail(6)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2021-07-14  35.500000  35.700001  34.860001  35.009998  35.009998
# 2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001

# %%
cotacoes.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Cotações dos 100 pregões mais recentes (considerando que as datas estão ordenadas)
cotacoes.tail(100).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# slicing

cotacoes[-3:]
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001

# %%
cotacoes.tail(3)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001

# %%
cotacoes[-50:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cotacoes.loc['2018-01-01':'2019-01-01'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cotacoes.iloc[15:25].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adjusted = ['Adj Close']
adj_close = cotacoes[adjusted]
adj_close.head()
# Out:
#             Adj Close
# Date
# 2017-07-24   7.051007
# 2017-07-25   6.996235
# 2017-07-26   6.956069
# 2017-07-27   6.901296
# 2017-07-28   6.835570

# %%
adj_close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Bibliotecas de Mercado Financeiro

# %%
import yfinance as yf

yf.download('FB').Close.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:xlabel='Date'>

# %%
data = yf.download('AAPL', start='2017-01-01', end='2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Outros dados sobre os ativos

coke = yf.Ticker('KO')
coke.info
# Out:
# {'zip': '30313',
#  'sector': 'Consumer Defensive',
#  'fullTimeEmployees': 79000,
# ...

# %%
# Traz histórico de cotações e eventos
hist = coke.history(period='max')
hist.head()
# Out:
#                 Open      High       Low     Close   Volume  Dividends  \
# Date
# 1962-01-02  0.050381  0.051752  0.050381  0.050381   806400        0.0
# 1962-01-03  0.049632  0.049632  0.048510  0.049258  1574400        0.0
# 1962-01-04  0.049383  0.050006  0.049383  0.049632   844800        0.0
# 1962-01-05  0.049632  0.050256  0.048385  0.048510  1420800        0.0
# 1962-01-08  0.048136  0.048136  0.047076  0.048011  2035200        0.0
#
#             Stock Splits
# Date
# 1962-01-02           0.0
# 1962-01-03           0.0
# 1962-01-04           0.0
# 1962-01-05           0.0
# 1962-01-08           0.0

# %%
hist.Close.plot();

# %%
# histórico de dividendos
hist.Dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
hist.shape
# Out:
# (15222, 7)

# %%
hist.Dividends.iloc[14197:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Também traz os eventos
coke.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1962-03-13   0.001563           0.0
# 1962-06-11   0.001563           0.0
# 1962-09-11   0.001563           0.0
# 1962-11-28   0.001563           0.0
# 1963-03-11   0.001758           0.0
# ...               ...           ...
# 2021-06-14   0.420000           0.0
# 2021-09-14   0.420000           0.0
# 2021-11-30   0.420000           0.0
# 2022-03-14   0.440000           0.0
# 2022-06-14   0.440000           0.0
#
# [249 rows x 2 columns]

# %%
coke.dividends
# Out:
# Date
# 1962-03-13    0.001563
# 1962-06-11    0.001563
# 1962-09-11    0.001563
# 1962-11-28    0.001563
# 1963-03-11    0.001758
#                 ...
# 2021-06-14    0.420000
# 2021-09-14    0.420000
# 2021-11-30    0.420000
# 2022-03-14    0.440000
# 2022-06-14    0.440000
# Name: Dividends, Length: 241, dtype: float64

# %%
# Demonstrativos financeiros
coke.financials
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       12425000000.0   9749000000.0
# Minority Interest                        1861000000.0   1985000000.0
# Net Income                               9771000000.0   7747000000.0
# Selling General Administrative          11984000000.0   9579000000.0
# Gross Profit                            23298000000.0  19581000000.0
# Ebit                                    11321000000.0   9990000000.0
# Operating Income                        11321000000.0   9990000000.0
# Other Operating Expenses                   -7000000.0     12000000.0
# Interest Expense                        -1597000000.0  -1437000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
coke.quarterly_financials
# Out:
#                                            2022-04-01    2021-12-31  \
# Research Development                             None          None
# Effect Of Accounting Charges                     None          None
# Income Before Tax                        3458000000.0  2960000000.0
# Minority Interest                        1996000000.0  1861000000.0
# Net Income                               2781000000.0  2414000000.0
# Selling General Administrative           2897000000.0  3382000000.0
# Gross Profit                             6400000000.0  5376000000.0
# Ebit                                     3503000000.0  2001000000.0
# Operating Income                         3503000000.0  2001000000.0
# Other Operating Expenses                          NaN    -7000000.0
# Interest Expense                         -182000000.0  -165000000.0
# Extraordinary Items                              None          None
# Non Recurring                                    None          None
# ...

# %%
coke.major_holders
# Out:
#         0                                      1
# 0   0.66%        % of Shares Held by All Insider
# 1  70.74%       % of Shares Held by Institutions
# 2  71.21%        % of Float Held by Institutions
# 3    3463  Number of Institutions Holding Shares

# %%
coke.institutional_holders
# Out:
#                                        Holder     Shares Date Reported  \
# 0                     Berkshire Hathaway, Inc  400000000    2022-03-30
# 1                  Vanguard Group, Inc. (The)  351220018    2022-03-30
# 2                              Blackrock Inc.  279114132    2022-03-30
# 3                    State Street Corporation  171972013    2022-03-30
# 4                                    FMR, LLC   83088402    2022-03-30
# 5            Wellington Management Group, LLP   80654038    2022-03-30
# 6                   JP Morgan Chase & Company   70822837    2022-03-30
# 7               Geode Capital Management, LLC   70444447    2022-03-30
# 8  Charles Schwab Investment Management, Inc.   51570921    2022-03-30
# 9                              Morgan Stanley   51062192    2022-03-30
#
#     % Out        Value
# 0  0.0923  24800000000
# 1  0.0810  21775641116
# 2  0.0644  17305076184
# 3  0.0397  10662264806
# 4  0.0192   5151480924
# 5  0.0186   5000550356
# ...

# %%
coke.balance_sheet
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 1.525000e+10  1.104400e+10  1.000200e+10
# Capital Surplus                   1.811600e+10  1.760100e+10  1.715400e+10
# Total Liab                        6.949400e+10  6.601200e+10  6.528300e+10
# Total Stockholder Equity          2.299900e+10  1.929900e+10  1.898100e+10
# Minority Interest                 1.861000e+09  1.985000e+09  2.117000e+09
# Other Current Liab                1.859000e+09  2.010000e+09  1.636000e+09
# Total Assets                      9.435400e+10  8.729600e+10  8.638100e+10
# Common Stock                      1.760000e+09  1.760000e+09  1.760000e+09
# Other Current Assets              1.018000e+09  1.520000e+08  5.700000e+07
# Retained Earnings                 6.909400e+10  6.655500e+10  6.585500e+10
# Other Liab                        1.025300e+10  9.986000e+09  9.662000e+09
# ...

# %%
coke.quarterly_balance_sheet
# Out:
#                                     2022-04-01    2021-12-31    2021-10-01  \
# Intangible Assets                 1.514200e+10  1.525000e+10  1.094500e+10
# Capital Surplus                   1.838800e+10  1.811600e+10  1.792900e+10
# Total Liab                        6.722300e+10  6.949400e+10  6.647300e+10
# Total Stockholder Equity          2.484500e+10  2.299900e+10  2.217900e+10
# Minority Interest                 1.996000e+09  1.861000e+09  1.954000e+09
# Other Current Liab                9.740000e+08  1.859000e+09  9.240000e+08
# Total Assets                      9.406400e+10  9.435400e+10  9.060600e+10
# Common Stock                      1.760000e+09  1.760000e+09  1.760000e+09
# Other Current Assets              1.261000e+09  1.018000e+09  2.660000e+08
# Retained Earnings                 6.996900e+10  6.909400e+10  6.849400e+10
# Other Liab                        1.094200e+10  1.025300e+10  1.108900e+10
# ...

# %%
coke.cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.029000e+09  2.520000e+08
# Change To Liabilities                      2.843000e+09 -8.600000e+08
# Total Cashflows From Investing Activities -2.765000e+09 -1.477000e+09
# Net Borrowings                             2.280000e+08 -1.862000e+09
# Total Cash From Financing Activities      -6.786000e+09 -8.070000e+09
# Change To Operating Activities            -5.920000e+08  5.850000e+08
# Issuance Of Stock                          7.020000e+08  6.470000e+08
# Net Income                                 9.771000e+09  7.747000e+09
# Change In Cash                             2.915000e+09  3.730000e+08
# Repurchase Of Stock                       -1.110000e+08 -1.180000e+08
# Effect Of Exchange Rate                   -1.590000e+08  7.600000e+07
# Total Cash From Operating Activities       1.262500e+10  9.844000e+09
# ...

# %%
coke.earnings
# Out:
#           Revenue    Earnings
# Year
# 2018  34300000000  6434000000
# 2019  37266000000  8920000000
# 2020  33014000000  7747000000
# 2021  38655000000  9771000000

# %%
coke.quarterly_earnings
# Out:
#              Revenue    Earnings
# Quarter
# 3Q2021   10129000000  2641000000
# 4Q2021   10042000000  2471000000
# 4Q2021    9464000000  2414000000
# 2Q2022   10491000000  2781000000

# %%
coke.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-07-19 12:30:00  2022-07-25 12:30:00
# Earnings Average                 0.67                 0.67
# Earnings Low                     0.61                 0.61
# Earnings High                    0.74                 0.74
# Revenue Average           10560500000          10560500000
# Revenue Low                9171000000           9171000000
# Revenue High              11104000000          11104000000

# %% [markdown]
# # Biblioteca yahoo_fin

# %%
from yahoo_fin import stock_info as si

si.get_live_price('AAPL')
# Out:
# 135.8699951171875

# %%
import time
from datetime import datetime

df = pd.DataFrame(columns=['DateTime', 'Quote'])
a = 0
t_end = time.time() + 60*5
while time.time() < t_end:
    x = si.get_live_price('PETR4.SA')
    timestampStr = datetime.now().strftime('%d-%b-%Y %H:%M:%S')
    d = {'DateTime': timestampStr, 'Quote': round(x,2)}
    linha = pd.DataFrame(data=d, index=[a])
    a += 1
    df = pd.concat([df, linha], ignore_index=True)
    time.sleep(1)

# %%
df.head()
# Out:
#                DateTime  Quote
# 0  22-Jun-2022 14:55:01  27.31
# 1  22-Jun-2022 14:55:03  27.31
# 2  22-Jun-2022 14:55:05   27.3
# 3  22-Jun-2022 14:55:07  27.31
# 4  22-Jun-2022 14:55:09   27.3

# %%
df.index = df.DateTime

# %%
df.Quote.plot()
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# # Biblioteca pandas_datareader

# %%
import pandas_datareader as pdr
import pandas as pd

# %%
dados = pdr.data.get_data_yahoo('WEGE3.SA', start='2019-01-01')
dados.head()
# Out:
#              High   Low   Open  Close     Volume  Adj Close
# Date
# 2019-01-02  9.090  8.75  8.810  8.990  4751200.0   8.611478
# 2019-01-03  9.195  8.85  9.000  9.195  8316400.0   8.807848
# 2019-01-04  9.340  9.00  9.200  9.300  8340200.0   8.908427
# 2019-01-07  9.380  9.10  9.375  9.155  5860200.0   8.769531
# 2019-01-08  9.215  9.02  9.185  9.080  6306800.0   8.697688

# %%
inicio = '2020-01-01'
acoes = ['PETR4.SA', 'WEGE3.SA', 'MGLU3.SA', 'LREN3.SA', 'VALE3.SA', 'BPAC11.SA']
preco_acoes = pd.DataFrame()
for acao in acoes:
    preco_acoes[acao] = pdr.data.get_data_yahoo(acao, start=inicio)['Adj Close']

# %%
preco_acoes.head()
# Out:
#              PETR4.SA   WEGE3.SA   MGLU3.SA   LREN3.SA   VALE3.SA  BPAC11.SA
# Date
# 2020-01-02  20.466219  17.142603  12.029734  54.897705  42.689384  18.235775
# 2020-01-03  20.299557  16.923702  11.922436  54.515804  42.375092  18.288696
# 2020-01-06  20.539551  16.967482  11.932189  54.468067  42.123653  18.262236
# 2020-01-07  20.459551  17.098825  11.898049  54.439423  42.430092  18.335096
# 2020-01-08  20.332890  16.451841  12.263843  54.792690  42.437946  18.172602

# %%
preco_acoes.plot()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-93gsadv8 because the default path (/home/mbaltar/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Biblioteca investpy

# %%
import investpy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ações

# %%
search_results = investpy.search_quotes(text='PETRO', products=['stocks'], countries=['brazil'], n_results=50)
for resultado in search_results[0:10]:
    print(resultado)
# Out:
# {"id_": 18749, "name": "Petroleo Brasileiro SA", "symbol": "PETR3", "country": "brazil", "tag": "/equities/petrobras-on", "pair_type": "stocks", "exchange": "BM&FBovespa"}
# {"id_": 18750, "name": "Petroleo Brasileiro SA PN", "symbol": "PETR4", "country": "brazil", "tag": "/equities/petrobras-pn", "pair_type": "stocks", "exchange": "BM&FBovespa"}
# {"id_": 18697, "name": "Petro Rio SA", "symbol": "PRIO3", "country": "brazil", "tag": "/equities/hrt-petroleo-on-nm", "pair_type": "stocks", "exchange": "BM&FBovespa"}
# {"id_": 1167309, "name": "3R Petroleum Oleo E Gas\u00a0Sa", "symbol": "RRRP3", "country": "brazil", "tag": "/equities/3r-petroleum-oleo-e-gas-sa", "pair_type": "stocks", "exchange": "BM&FBovespa"}
# {"id_": 1172772, "name": "Petroreconcavo SA", "symbol": "RECV3", "country": "brazil", "tag": "/equities/petroreconcavo", "pair_type": "stocks", "exchange": "BM&FBovespa"}
# ...

# %%
# Instrutor do curso fez gambiarra... Viu o que queria na pesquisa acima e limitou o retorno da função para pegar só um registro
for resultado in search_results[1:2]:
    print(resultado)
# Out:
# {"id_": 18750, "name": "Petroleo Brasileiro SA PN", "symbol": "PETR4", "country": "brazil", "tag": "/equities/petrobras-pn", "pair_type": "stocks", "exchange": "BM&FBovespa"}

# %%
petr = resultado.retrieve_historical_data(from_date='01/01/2014', to_date='01/06/2021')
petr.head()
# Out:
#              Open   High    Low  Close    Volume  Change Pct
# Date
# 2014-01-02  15.49  15.54  15.04  15.13  17111300       -1.94
# 2014-01-03  15.12  15.16  14.83  14.83  17598400       -1.98
# 2014-01-06  14.86  15.03  14.60  15.01  20474600        1.21
# 2014-01-07  15.04  15.20  14.60  14.60  18785300       -2.73
# 2014-01-08  14.70  14.81  14.59  14.62  15558400        0.14

# %%
petr['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Outra forma de buscar preço das ações
investpy.stocks.get_stock_historical_data('PETR4', from_date='01/01/2014', to_date='01/06/2021', country='brazil')
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2014-01-02  15.49  15.54  15.04  15.13   17111300      BRL
# 2014-01-03  15.12  15.16  14.83  14.83   17598400      BRL
# 2014-01-06  14.86  15.03  14.60  15.01   20474600      BRL
# 2014-01-07  15.04  15.20  14.60  14.60   18785300      BRL
# 2014-01-08  14.70  14.81  14.59  14.62   15558400      BRL
# ...           ...    ...    ...    ...        ...      ...
# 2021-05-26  25.91  26.18  25.65  26.09   46252000      BRL
# 2021-05-27  26.08  26.25  25.77  25.91   48450100      BRL
# 2021-05-28  26.20  27.02  26.15  26.99  128991904      BRL
# 2021-05-31  26.96  27.20  26.78  26.87   46031300      BRL
# 2021-06-01  27.40  27.70  27.01  27.29   90018200      BRL
#
# [1833 rows x 6 columns]

# %% [markdown]
# ## Índices

# %%
search_results = investpy.search_quotes(text='bvsp', products=['indices'], countries=['brazil'], n_results=50)
for resultado in search_results:
    print(resultado)
# Out:
# {"id_": 17920, "name": "Bovespa", "symbol": "BVSP", "country": "brazil", "tag": "/indices/bovespa", "pair_type": "indices", "exchange": "BM&FBovespa"}
# {"id_": 49632, "name": "Ibovespa USD", "symbol": "BVSPUSD", "country": "brazil", "tag": "/indices/ibovespa-usd", "pair_type": "indices", "exchange": "BM&FBovespa"}
# {"id_": 49633, "name": "Ibovespa EUR", "symbol": "BVSPEUR", "country": "brazil", "tag": "/indices/ibovespa-eur", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
search_results = investpy.search_quotes(text='bvsp', products=['indices'], countries=['brazil'], n_results=50)
for resultado in search_results[:1]:
    print(resultado)
# Out:
# {"id_": 17920, "name": "Bovespa", "symbol": "BVSP", "country": "brazil", "tag": "/indices/bovespa", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
ibov = resultado.retrieve_historical_data(from_date='01/01/2014', to_date='01/06/2021')
ibov.head()
# Out:
#                Open     High      Low    Close   Volume  Change Pct
# Date
# 2014-01-02  51522.0  51656.0  50246.0  50341.0  3476344       -2.26
# 2014-01-03  50348.0  50981.0  50269.0  50981.0  7360435        1.27
# 2014-01-06  50980.0  51002.0  50451.0  50974.0  3727849       -0.01
# 2014-01-07  50982.0  51478.0  50429.0  50430.0  3339481       -1.07
# 2014-01-08  50431.0  50793.0  50424.0  50577.0  2916519        0.29

# %%
ibov = investpy.indices.get_index_historical_data('Bovespa', from_date='01/01/2014', to_date='01/06/2021', country='brazil')

# %%
ibov.head()
# Out:
#                Open     High      Low    Close   Volume Currency
# Date
# 2014-01-02  51522.0  51656.0  50246.0  50341.0  3476344      BRL
# 2014-01-03  50348.0  50981.0  50269.0  50981.0  7360435      BRL
# 2014-01-06  50980.0  51002.0  50451.0  50974.0  3727849      BRL
# 2014-01-07  50982.0  51478.0  50429.0  50430.0  3339481      BRL
# 2014-01-08  50431.0  50793.0  50424.0  50577.0  2916519      BRL

# %%
ibov_usd = investpy.indices.get_index_historical_data('Ibovespa USD', from_date='01/01/2014', to_date='01/06/2021', country='brazil')

# %%
ibov_usd['Close'].plot();

# %% [markdown]
# ## ETFs

# %%
bova11 = investpy.get_etf_historical_data(etf='Ishares Ibovespa', from_date='01/01/2014', to_date='01/06/2021', country='brazil')
bova11['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gld = investpy.get_etf_historical_data(etf='SPDR Gold Shares', from_date='01/01/2014', to_date='01/06/2021', country='united states')
gld['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Commodities

# %%
# Soja
search_results = investpy.search_quotes(text='soy', products=['commodities'], countries=['brazil'], n_results=50)
for resultado in search_results:
    print(resultado)
# Out:
# {"id_": 964523, "name": "US Soybeans Futures", "symbol": "SJCc1", "country": null, "tag": "/commodities/us-soybeans?cid=964523", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
soja = resultado.retrieve_historical_data(from_date='01/01/2014', to_date='01/01/2022')

# %%
soja['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Milho: 'corn'; Boi Gordo: 'cattle', Madeira usada para construção civil nos EUA: 'lumber'; Urânio: 'uranium'

# %% [markdown]
# ## Criptomoedas

# %%
bitcoin = investpy.get_crypto_historical_data(crypto='bitcoin', from_date='01/01/2014', to_date='15/05/2022')
bitcoin.head()
# Out:
#              Open    High    Low   Close  Volume Currency
# Date
# 2014-01-01  805.9   829.9  771.0   815.9   10757      USD
# 2014-01-02  815.9   886.2  810.5   856.9   12812      USD
# 2014-01-03  856.9   888.2  839.4   884.3    9709      USD
# 2014-01-04  884.3   932.2  848.3   924.7   14239      USD
# 2014-01-05  924.7  1029.9  911.4  1014.7   21374      USD

# %%
bitcoin['Close'].plot();

# %% [markdown]
# ## Tesouro Direto

# %%
search_results = investpy.search_quotes(text='tesouro', products=['bonds'], countries=['brazil'], n_results=50)
for resultado in search_results:
    print(resultado)
# Out:
# {"id_": 1089868, "name": "Tesouro Selic LFT 0 01-Mar-2023", "symbol": "LFT030123=RRPS", "country": "brazil", "tag": "/rates-bonds/lft-0-01-mar-2023", "pair_type": "bonds", "exchange": "OTC Bonds"}
# {"id_": 1089892, "name": "Tesouro IPCA + NTNB 6 15-Mar-2023", "symbol": "NTB031523=", "country": "brazil", "tag": "/rates-bonds/ntnb-6-15-mar-2023", "pair_type": "bonds", "exchange": "OTC Bonds"}
# {"id_": 1089869, "name": "Tesouro Selic LFT 0 01-Mar-2024", "symbol": "LFT030124=ANDS", "country": "brazil", "tag": "/rates-bonds/lft-0-01-mar-2024", "pair_type": "bonds", "exchange": "OTC Bonds"}
# {"id_": 1172586, "name": "Tesouro Selic Vencimento em 01/03/2027", "symbol": "LFT030127=ANDS", "country": "brazil", "tag": "/rates-bonds/brstnclf1rg5", "pair_type": "bonds", "exchange": "OTC Bonds"}
# {"id_": 1094220, "name": "Tesouro Prefixado LTN 0 01-Jan-2023", "symbol": "LTN010123=RRPS", "country": "brazil", "tag": "/rates-bonds/ltn-0-01-jan-2023", "pair_type": "bonds", "exchange": "OTC Bonds"}
# ...
